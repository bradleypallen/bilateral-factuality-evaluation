# %%
from judges import BilateralJudge
from IPython.display import display, Markdown

# %%
MODEL = "google/gemini-2.0-flash-001"

# %%
EXAMPLES = [
    {   
        "question": "Chocolate is made from material",
        "answer": "Sugar"
    },
    {
        "question": "Who was the first man to walk on the Moon?",
        "answer": "Neil Armstrong"
    }, 
    {
        "question": "Who was the first man to walk on the Moon?",
        "answer": "Pete Conrad"
    }, 
    {
        "question": "Are penguins birds?",
        "answer": "No"
    },
    {
        "question": "Who was the frobnoz that restified the branks?",
        "answer": "Rutherford B. Hayes"
    },
    {
        "question": "When was America discovered?",
        "answer": "1492"
    },
    {
        "question": "Did Lee Harvey Oswald act alone in the assassination of John Kennedy?",
        "answer": "Yes"
    },
    {
        "question": "Is the Holy Trinity one entity or three entities?",
        "answer": "Three"
    },
]

# %%
def bilateral_evaluation(example):
    bilateral_evaluator = BilateralJudge(MODEL)
    evaluation = bilateral_evaluator.invoke("test_examples", example, samples=3)
    display(Markdown(f"### Reasoning"))
    display(Markdown(f"#### Verifications"))
    for i, v in enumerate(evaluation["verifications"]):
        display(Markdown(f"##### Verification {i+1}"))
        display(Markdown(f"{v}"))
    display(Markdown(f"#### Refutations"))
    for i, r in enumerate(evaluation["refutations"]):
        display(Markdown(f"##### Refutation {i+1}"))
        display(Markdown(f"{r}"))
    display(Markdown(f"### Evaluation: {evaluation['I']}"))
    display(Markdown(f"### Execution time: {evaluation['execution_time']:.2f} seconds"))
    display(Markdown(f"### Tokens used: {evaluation['tokens_used']:5d}"))

# %%
for example in EXAMPLES:
    display(Markdown(f'# {example["question"]} {example["answer"]}'))
    bilateral_evaluation(example)
# Out:
# # Chocolate is made from material Sugar
# ### Reasoning
# #### Verifications
# ##### Verification 1
# CANNOT VERIFY
# ##### Verification 2
# CANNOT VERIFY
# ##### Verification 3
# CANNOT VERIFY
# #### Refutations
# ##### Refutation 1
# REFUTED
# ##### Refutation 2
# REFUTED
# ##### Refutation 3
# REFUTED
# ### Evaluation: <f,t>
# ### Execution time: 3.23 seconds
# ### Tokens used:   321
# # Who was the first man to walk on the Moon? Neil Armstrong
# ### Reasoning
# #### Verifications
# ##### Verification 1
# VERIFIED
# ##### Verification 2
# VERIFIED
# ##### Verification 3
# VERIFIED
# #### Refutations
# ##### Refutation 1
# CANNOT REFUTE
# ##### Refutation 2
# CANNOT REFUTE
# ##### Refutation 3
# CANNOT REFUTE
# ### Evaluation: <t,f>
# ### Execution time: 3.85 seconds
# ### Tokens used:   363
# # Who was the first man to walk on the Moon? Pete Conrad
# ### Reasoning
# #### Verifications
# ##### Verification 1
# The proposed answer is incorrect. The first man to walk on the Moon was Neil Armstrong.
#
# CANNOT VERIFY
# ##### Verification 2
# The proposed answer is incorrect. The first man to walk on the Moon was Neil Armstrong.
#
# CANNOT VERIFY
# ##### Verification 3
# The proposed answer is incorrect. The first man to walk on the Moon was Neil Armstrong.
#
# CANNOT VERIFY
# #### Refutations
# ##### Refutation 1
# REFUTED
# ##### Refutation 2
# REFUTED
# ##### Refutation 3
# REFUTED
# ### Evaluation: <f,t>
# ### Execution time: 3.39 seconds
# ### Tokens used:   420
# # Are penguins birds? No
# ### Reasoning
# #### Verifications
# ##### Verification 1
# CANNOT VERIFY
# ##### Verification 2
# CANNOT VERIFY
# ##### Verification 3
# CANNOT VERIFY
# #### Refutations
# ##### Refutation 1
# REFUTED
# ##### Refutation 2
# REFUTED
# ##### Refutation 3
# REFUTED
# ### Evaluation: <f,t>
# ### Execution time: 4.16 seconds
# ### Tokens used:   315
# # Who was the frobnoz that restified the branks? Rutherford B. Hayes
# ### Reasoning
# #### Verifications
# ##### Verification 1
# CANNOT VERIFY
# ##### Verification 2
# CANNOT VERIFY
# ##### Verification 3
# CANNOT VERIFY
# #### Refutations
# ##### Refutation 1
# CANNOT REFUTE
# ##### Refutation 2
# CANNOT REFUTE
# ##### Refutation 3
# CANNOT REFUTE
# ### Evaluation: <f,f>
# ### Execution time: 3.77 seconds
# ### Tokens used:   393
# # When was America discovered? 1492
# ### Reasoning
# #### Verifications
# ##### Verification 1
# VERIFIED
# ##### Verification 2
# VERIFIED
# ##### Verification 3
# VERIFIED
# #### Refutations
# ##### Refutation 1
# CANNOT REFUTE
# ##### Refutation 2
# CANNOT REFUTE
# ##### Refutation 3
# CANNOT REFUTE
# ### Evaluation: <t,f>
# ### Execution time: 3.23 seconds
# ### Tokens used:   345
# # Did Lee Harvey Oswald act alone in the assassination of John Kennedy? Yes
# ### Reasoning
# #### Verifications
# ##### Verification 1
# CANNOT VERIFY
# ##### Verification 2
# CANNOT VERIFY
# ##### Verification 3
# CANNOT VERIFY
# #### Refutations
# ##### Refutation 1
# REFUTED
# ##### Refutation 2
# REFUTED
# ##### Refutation 3
# REFUTED
# ### Evaluation: <f,t>
# ### Execution time: 3.69 seconds
# ### Tokens used:   369
# # Is the Holy Trinity one entity or three entities? Three
# ### Reasoning
# #### Verifications
# ##### Verification 1
# VERIFIED
# ##### Verification 2
# VERIFIED
# ##### Verification 3
# VERIFIED
# #### Refutations
# ##### Refutation 1
# CANNOT REFUTE
# ##### Refutation 2
# CANNOT REFUTE
# ##### Refutation 3
# CANNOT REFUTE
# ### Evaluation: <t,f>
# ### Execution time: 4.82 seconds
# ### Tokens used:   351
